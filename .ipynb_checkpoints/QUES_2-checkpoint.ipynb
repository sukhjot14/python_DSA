# %%
# Multiplication table

def table(n):
    for i in range(1,11):
        print(n,"*",i,"=",n*i)

n=6
table(n)
# Out:
# 6 * 1 = 6
# 6 * 2 = 12
# 6 * 3 = 18
# 6 * 4 = 24
# 6 * 5 = 30
# 6 * 6 = 36
# 6 * 7 = 42
# 6 * 8 = 48
# 6 * 9 = 54
# 6 * 10 = 60

# %%
def table(n):
    for i in range(1,11):
        print("%d * %d = %d" % (n,i,n*i))

n=13
table(n)
# Out:
# 13 * 1 = 13
# 13 * 2 = 26
# 13 * 3 = 39
# 13 * 4 = 52
# 13 * 5 = 65
# 13 * 6 = 78
# 13 * 7 = 91
# 13 * 8 = 104
# 13 * 9 = 117
# 13 * 10 = 130
